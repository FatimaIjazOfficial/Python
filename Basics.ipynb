# %% [markdown]
# # 🐍 Python Basics
#
# In this notebook, we will learn:

# %% [markdown]
# ### - Variables & DataTypes

# %%
name = "Fatima"   # String
age = 22          # Int
height = 5.4      # Float
is_student = True # Boolean

# %% [markdown]
# ### - Type Checking & Type Conversion

# %%
type(age)
# Out:
# int

# %%
str_age = str(age)
str_age
# Out:
# '22'

# %%
type(str_age)
# Out:
# str
